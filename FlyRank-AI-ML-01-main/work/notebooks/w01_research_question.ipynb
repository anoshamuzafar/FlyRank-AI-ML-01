# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 1: Ranking Signal Analysis. I chose this because I want to analyze which features directly help in driving clicks and views.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
1. Decision & Action:
This work will help the teams working to decide which data signals should be prioritized in recommendation to maximize user engagement. The development team can optimize the model's feature engineering process rather than wasting computational resources on irrelevant data.

2. The Cost of a Wrong Call:
If one makes a wrong call and prioritizes weak signals, the algorithm will recommend irrelevant items to users, leading to a direct drop in CTR and user retention. Furthermore, the team would waste valuable engineering hours and cloud computing costs training models on the wrong features.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# %pip install pandas
# Out:
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.8 MB 1.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.8 MB 2.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.8 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.8 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/9.8 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 2.0 MB/s eta 0:00:04
# ...

# %%
import pandas as pd
import os

path_1 = '../data/raw/content_refresh_anonymized.csv'
path_2 = '../../data/raw/content_refresh_anonymized.csv'
path_3 = 'data/raw/content_refresh_anonymized.csv'


if os.path.exists(path_1):
    file_path = path_1
elif os.path.exists(path_2):
    file_path = path_2
elif os.path.exists(path_3):
    file_path = path_3
else:
    file_path = r"C:\Users\MR COMPUTER\Desktop\FlyRank\Machine learning\FlyRank-AI-ML-01-main\data\raw\content_refresh_anonymized.csv"

df = pd.read_csv(file_path)

print(f"Total rows in dataset: {df.shape[0]}")
print(f"Total features/columns: {df.shape[1]}")
print("\nA quick look at the first few rows:")
df.head()
# Out:
# Total rows in dataset: 30000
# Total features/columns: 44
#
# A quick look at the first few rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
I can claim that this work will provide observed, directional decision-support by highlighting correlations—showing which user behavioral features are strongly linked with higher clicks.
I cannot claim causal proof (that X causes Y definitively) or predict human behavior perfectly, nor do I claim this model will match industry giants like Google's production ranking algorithms.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
